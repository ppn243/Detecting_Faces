# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
! git clone https://github.com/ultralytics/yolov5
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %% [markdown]
# # Import Library

# %%
! pip install -r yolov5/requirements.txt

# %% [markdown]
# # Model Training

# %%
! python yolov5/train.py --img 640 --batch 32 --epochs 20 --data /content/drive/MyDrive/Face_Mask_Detect/Data/data.yaml --weights yolov5s.pt
# Out:
# 2023-11-29 16:40:15.325273: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-29 16:40:15.325341: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-29 16:40:15.325386: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# # Model Inference

# %%
! cp /content/yolov5/runs/train/exp2/weights/best.pt /content/drive/MyDrive/Face_Mask_Detect
